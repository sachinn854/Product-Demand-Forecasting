# %%
import pandas as pd

# %%
final_df=pd.read_csv("Master_file.csv")

# %%
final_df.describe(include='all').T
# Out:
#                         count unique         top    freq         mean  \
# productid              511809    500       P0045    1112          NaN
# location               511809     10         L04  140104          NaN
# date                   511809    365  2024-06-10    1521          NaN
# unitssold            511809.0    NaN         NaN     NaN     5.000035
# promocodeused          511809      2          No  299233          NaN
# price                511809.0    NaN         NaN     NaN   300.372553
# discount_percent     511809.0    NaN         NaN     NaN     2.897223
# competitorprice      511809.0    NaN         NaN     NaN   315.402419
# adcampaign             134768      2          Tv   78430          NaN
# finalprice           511809.0    NaN         NaN     NaN   291.686713
# isweekend              511809      2          No  365987          NaN
# season                 511809      4      Summer  129650          NaN
# daytype                511809      3     Weekday  356034          NaN
# temp(c)              511809.0    NaN         NaN     NaN    25.901659
# rainfall(mm)         511809.0    NaN         NaN     NaN    10.432597
# category               511809      5      Beauty  114766          NaN
# brand                  511809      4      BrandA  146229          NaN
# material               511809      5       Metal  110130          NaN
# weight(kg)           511809.0    NaN         NaN     NaN     2.625807
# warranty(years)      511809.0    NaN         NaN     NaN     1.480277
# productrating        511809.0    NaN         NaN     NaN     3.803459
# launchyear           511809.0    NaN         NaN     NaN  2020.503485
# stocklevel           511809.0    NaN         NaN     NaN   103.937662
# supplierdelay(days)  511809.0    NaN         NaN     NaN     5.335623
# warehouse              511809      3          W3  173130          NaN
# inventorytype          511809      4       Fresh  178328          NaN
#
#                            std     min      25%      50%      75%     max
# productid                  NaN     NaN      NaN      NaN      NaN     NaN
# location                   NaN     NaN      NaN      NaN      NaN     NaN
# date                       NaN     NaN      NaN      NaN      NaN     NaN
# unitssold             3.162425     0.0      2.0      5.0      8.0    10.0
# promocodeused              NaN     NaN      NaN      NaN      NaN     NaN
# price                59.169986  100.01    300.5    300.5    300.5   500.0
# discount_percent      5.813078     0.0      0.0      0.0      0.0    20.0
# competitorprice      63.823479   90.24  315.525  315.525  315.525   599.5
# adcampaign                 NaN     NaN      NaN      NaN      NaN     NaN
# finalprice           55.688089  80.016    300.5    300.5    300.5  499.99
# isweekend                  NaN     NaN      NaN      NaN      NaN     NaN
# season                     NaN     NaN      NaN      NaN      NaN     NaN
# daytype                    NaN     NaN      NaN      NaN      NaN     NaN
# temp(c)                 8.7318     5.0     19.6     26.6     32.6    45.0
# rainfall(mm)         15.408521     0.0      2.1      5.1     12.1   120.0
# category                   NaN     NaN      NaN      NaN      NaN     NaN
# brand                      NaN     NaN      NaN      NaN      NaN     NaN
# material                   NaN     NaN      NaN      NaN      NaN     NaN
# weight(kg)            1.389854     0.2     1.41     2.71     3.83    4.98
# warranty(years)       1.144724     0.0      0.0      1.0      3.0     3.0
# productrating         0.716942     2.5      3.2      3.8      4.4     5.0
# launchyear            1.744057  2018.0   2019.0   2020.0   2022.0  2023.0
# stocklevel           55.269058    10.0     55.0    104.0    153.0   199.0
# supplierdelay(days)   2.868488     2.0      3.0      5.0      7.0    10.0
# warehouse                  NaN     NaN      NaN      NaN      NaN     NaN
# inventorytype              NaN     NaN      NaN      NaN      NaN     NaN

# %%
final_df.groupby('productid')['unitssold'].sum().sort_values(ascending=False).head(10)
# Out:
# productid
# P0045    5708
# P0487    5655
# P0348    5632
# P0265    5632
# P0004    5607
# P0468    5602
# P0156    5579
# P0435    5569
# P0278    5562
# P0165    5552
# Name: unitssold, dtype: int64

# %%
final_df['revenue'] = final_df['unitssold'] * final_df['price']
final_df.groupby('location')['revenue'].sum().sort_values(ascending=False)
# Out:
# location
# L04    2.103740e+08
# L07    1.358793e+08
# L03    1.257415e+08
# L01    1.010818e+08
# L10    4.925267e+07
# L05    4.301498e+07
# L06    3.938824e+07
# L08    3.038282e+07
# L02    2.018350e+07
# L09    1.332924e+07
# Name: revenue, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
sns.boxplot(data=final_df, x='season', y='unitssold')
plt.title('Units Sold Across Seasons')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(7, 4))
sns.histplot(final_df['unitssold'], kde=True, bins=30, color='skyblue')
plt.title('Distribution of Units Sold')
plt.xlabel('Units Sold')
plt.ylabel('Count')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(7, 4))
sns.histplot(final_df['price'], kde=True, bins=30, color='green')
plt.title('Price Distribution')
plt.xlabel('Price')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(7, 4))
sns.countplot(x='discount_percent', data=final_df, palette='coolwarm')
plt.title('Discount % Count')
plt.xlabel('Discount (%)')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\sachi\AppData\Local\Temp\ipykernel_3360\2214156011.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='discount_percent', data=final_df, palette='coolwarm')

# %%
plt.figure(figsize=(7, 4))
sns.histplot(final_df['competitorprice'], kde=True, bins=30, color='orange')
plt.title('Competitor Price Distribution')
plt.xlabel('Competitor Price')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(7, 4))
sns.histplot(final_df['finalprice'], kde=True, bins=30, color='purple')
plt.title('Final Price Distribution')
plt.xlabel('Final Price')
plt.tight_layout()
plt.show()

# %%
final_df.head(1)
# Out:
#   productid location        date  unitssold promocodeused   price  \
# 0     P0080      L04  2024-04-12          8            No  309.98
#
#    discount_percent  competitorprice adcampaign  finalprice  ... material  \
# 0              20.0           347.76         Tv     247.984  ...    Metal
#
#   weight(kg) warranty(years)  productrating  launchyear stocklevel  \
# 0       4.49               1            4.8        2020         61
#
#   supplierdelay(days) warehouse  inventorytype  revenue
# 0                   3        W2          Fresh  2479.84
#
# [1 rows x 27 columns]

# %%
plt.figure(figsize=(7, 4))
sns.histplot(final_df['temp(c)'], kde=True, bins=30, color='tomato')
plt.title('Temperature (°C) Distribution')
plt.xlabel('Temperature (C)')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(5, 4))
sns.countplot(x='promocodeused', data=final_df, palette='Set2')
plt.title('Promo Code Usage')
plt.xlabel('Promo Code Used')
plt.ylabel('Count')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\sachi\AppData\Local\Temp\ipykernel_3360\1353882599.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='promocodeused', data=final_df, palette='Set2')

# %%
plt.figure(figsize=(6, 4))
sns.countplot(x='adcampaign', data=final_df, palette='Set1')
plt.title('Ad Campaign Types')
plt.xlabel('Ad Campaign')
plt.ylabel('Count')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\sachi\AppData\Local\Temp\ipykernel_3360\4218164583.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='adcampaign', data=final_df, palette='Set1')

# %%
plt.figure(figsize=(6, 4))
sns.countplot(x='season', data=final_df, palette='coolwarm')
plt.title('Seasonal Distribution')
plt.xlabel('Season')
plt.ylabel('Count')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\sachi\AppData\Local\Temp\ipykernel_3360\1710473435.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='season', data=final_df, palette='coolwarm')

# %%
plt.figure(figsize=(7, 4))
sns.countplot(x='location', data=final_df, order=final_df['location'].value_counts().index, palette='Set3')
plt.title('Transactions per Location')
plt.xlabel('Location')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\sachi\AppData\Local\Temp\ipykernel_3360\2735845870.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='location', data=final_df, order=final_df['location'].value_counts().index, palette='Set3')

# %%
plt.figure(figsize=(6, 4))
sns.boxplot(data=final_df, x='promocodeused', y='unitssold', palette='Set2')
plt.title('Units Sold vs Promo Code Usage')
plt.xlabel('Promo Code Used')
plt.ylabel('Units Sold')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\sachi\AppData\Local\Temp\ipykernel_3360\576784323.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=final_df, x='promocodeused', y='unitssold', palette='Set2')

# %%
plt.figure(figsize=(6, 4))
sns.boxplot(data=final_df, x='season', y='unitssold', palette='muted')
plt.title('Units Sold in Different Seasons')
plt.xlabel('Season')
plt.ylabel('Units Sold')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\sachi\AppData\Local\Temp\ipykernel_3360\315421835.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=final_df, x='season', y='unitssold', palette='muted')

# %%
avg_revenue = final_df.groupby('location')['revenue'].mean().sort_values(ascending=False)

plt.figure(figsize=(8, 5))
sns.barplot(x=avg_revenue.index, y=avg_revenue.values, palette='viridis')
plt.title('Average Revenue per Location')
plt.xlabel('Location')
plt.ylabel('Avg Revenue')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\sachi\AppData\Local\Temp\ipykernel_3360\2810113227.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=avg_revenue.index, y=avg_revenue.values, palette='viridis')

# %%
ad_rev = final_df.groupby('adcampaign')['revenue'].mean().sort_values(ascending=False)

plt.figure(figsize=(6, 4))
sns.barplot(x=ad_rev.index, y=ad_rev.values, palette='pastel')
plt.title('Average Revenue by Ad Campaign Type')
plt.xlabel('Ad Campaign')
plt.ylabel('Avg Revenue')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\sachi\AppData\Local\Temp\ipykernel_3360\904634486.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=ad_rev.index, y=ad_rev.values, palette='pastel')

# %% [markdown]
# # Correlation Heatmap (Numerical Insights)

# %%
numeric_cols = final_df.select_dtypes(include='number')

# Compute correlation matrix
corr = numeric_cols.corr()

# Plot heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Heatmap")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Units Sold Over Time (Monthly Aggregation)

# %%
# Convert 'date' to datetime if not already
final_df['date'] = pd.to_datetime(final_df['date'])

# Extract month for trend
final_df['month'] = final_df['date'].dt.to_period('M')

monthly_sales = final_df.groupby('month')['unitssold'].sum()

# Plot
monthly_sales.plot(kind='line', marker='o', figsize=(10, 4), title='Monthly Units Sold Trend')
plt.ylabel('Units Sold')
plt.xlabel('Month')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
monthly_revenue = final_df.groupby('month')['revenue'].sum()

# Plot
monthly_revenue.plot(kind='line', marker='o', color='green', figsize=(10, 4), title='Monthly Revenue Trend')
plt.ylabel('Revenue')
plt.xlabel('Month')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
