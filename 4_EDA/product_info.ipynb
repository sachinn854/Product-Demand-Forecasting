# %% [markdown]
# <div style="font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif; background-color: #f8f8f8; color: #4A4A4A; line-height: 1.7; padding: 20px; border-radius: 8px; box-shadow: 0 4px 8px rgba(0,0,0,0.05);">
#
#   <h1 style="font-size: 2.8em; color: #FF5733; border-bottom: 4px solid #C70039; padding-bottom: 15px; margin-bottom: 30px; font-weight: 700; text-shadow: 1px 1px 2px rgba(0,0,0,0.1);">
#     1. Introduction and Objectives
#   </h1>
#
#   <p style="font-size: 1.2em; margin-bottom: 18px; font-weight: 400;">
#     The primary objective of this EDA is to understand the underlying patterns, distributions, and relationships within the product data.
#     We aim to uncover insights that can inform business decisions related to
#     <strong style="color: #FFC300; font-weight: 700;">product development</strong>,
#     <strong style="color: #FFC300; font-weight: 700;">marketing strategies</strong>, and
#     <strong style="color: #FFC300; font-weight: 700;">inventory management</strong>.
#   </p>
#
#   <p style="font-size: 1.2em; margin-bottom: 10px; font-weight: 400;">
#     Specifically, we will investigate:
#   </p>
#
#   <ul style="font-size: 1.2em; margin-left: 20px; font-weight: 400;">
#     <li>📦 Distribution of products across different <strong style="color: #33C7FF;">categories</strong> and <strong style="color: #33C7FF;">brands</strong>.</li>
#     <li>⚙️ Characteristics of products based on <strong style="color: #33C7FF;">material</strong>, <strong style="color: #33C7FF;">weight</strong>, and <strong style="color: #33C7FF;">warranty</strong>.</li>
#     <li>⭐ Performance indicators like <strong style="color: #33C7FF;">product ratings</strong>.</li>
#     <li>📈 Trends in <strong style="color: #33C7FF;">product launches over time</strong>.</li>
#   </ul>
#
# </div>

# %% [markdown]
# <div style="font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif; background-color: #f8f8f8; color: #4A4A4A; line-height: 1.7; padding: 20px; border-radius: 8px; box-shadow: 0 4px 8px rgba(0,0,0,0.05); margin-top: 40px;">
#
#   <h1 style="font-size: 2.6em; color: #FF5733; border-bottom: 4px solid #C70039; padding-bottom: 15px; margin-bottom: 30px; font-weight: 700; text-shadow: 1px 1px 2px rgba(0,0,0,0.1);">
#     2. Data Overview
#   </h1>
#
#   <h2 style="font-size: 2em; color: #33C7FF; margin-top: 25px; margin-bottom: 12px; font-weight: 600;">
#     Summary Statistics & Data Types
#   </h2>
#
#   <p style="font-size: 1.2em; margin-bottom: 20px; font-weight: 400;">
#     Even after performing data cleaning, it is a good practice to verify that data types and summary statistics are as expected.
#     This serves as a quick sanity check before deep analysis.
#   </p>
#
#   <ul style="font-size: 1.15em; line-height: 1.8; padding-left: 20px;">
#     <li>
#       <strong style="color: #FFC300;">Data Types:</strong> Ensure that numerical columns like
#       <em>Weight(kg)</em>, <em>Warranty(years)</em>, <em>ProductRating</em>, and <em>LaunchYear</em>
#       are treated as numeric types, while categorical columns like <em>Category</em>, <em>Brand</em>, and
#       <em>Material</em> are handled as strings or object types.
#     </li>
#     <li>
#       <strong style="color: #FFC300;">Summary Statistics:</strong>
#       <ul style="padding-left: 20px;">
#         <li>
#           <strong>Numerical Columns:</strong> Mean, median, standard deviation, minimum, maximum, and quartiles.
#         </li>
#         <li>
#           <strong>Categorical Columns:</strong> Count of unique values and most frequent categories.
#         </li>
#       </ul>
#     </li>
#   </ul>
#
# </div>

# %% [markdown]
# <div style="font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif; background-color: #fefefe; color: #4A4A4A; line-height: 1.7; padding: 20px; border-radius: 8px; box-shadow: 0 4px 8px rgba(0,0,0,0.05); margin-top: 40px;">
#
#   <h1 style="font-size: 2.6em; color: #FF5733; border-bottom: 4px solid #C70039; padding-bottom: 15px; margin-bottom: 30px; font-weight: 700; text-shadow: 1px 1px 2px rgba(0,0,0,0.1);">
#     3. Univariate Analysis
#   </h1>
#
#   <p style="font-size: 1.2em; margin-bottom: 20px; font-weight: 400;">
#     This section focuses on understanding the distribution of each variable independently.
#   </p>
#
# </div>

# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\sachi\OneDrive\Product Demand Forecasting\3_CLEANED DATA\product_info_cleaned.csv")

# %% [markdown]
# <h3 style="font-family:Segoe UI,Tahoma,Geneva,Verdana,sans-serif; font-size:2.2em; color:#2E86C1; border-bottom:2px solid #1B4F72; padding-bottom:6px; margin-top:30px; margin-bottom:15px; font-weight:600;">
#   3.1 Categorical Variables
# </h3>
#
# <h4 style="font-family:Segoe UI,Tahoma,Geneva,Verdana,sans-serif; font-size:1.5em; color: #1ceb65ff; margin-top:20px; margin-bottom:10px;">
#    Category
# </h4>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Count frequency of each category
category_counts = df['Category'].value_counts().reset_index()
category_counts.columns = ['Category', 'count']

# Plot
plt.figure(figsize=(10, 6))
sns.barplot(
    data=category_counts,
    x='Category',
    y='count',
    hue='Category',           # <--- Fix: assign hue to x variable
    palette='viridis',
    legend=False              # <--- Hide legend since hue is same as x
)

# Formatting
plt.title('Distribution of Product Categories', fontsize=14, fontweight='bold')
plt.xlabel('Category', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif; background-color: #ffffff; color: #333333; padding: 20px; line-height: 1.8; border-radius: 8px; box-shadow: 0 2px 6px rgba(0,0,0,0.05); margin-top: 30px;">
#
#   <p style="font-size: 18px; font-weight: 600; color: #2c3e50; margin-bottom: 15px;">
#     📊 This graph displays the distribution of product categories.
#   </p>
#
#   <ul style="font-size: 16px; padding-left: 20px;">
#     <li><b>Beauty</b> is the most frequent category, with a count of approximately <b>115</b> products.</li>
#     <li><b>Clothing</b> is the second most frequent, with a count of about <b>110</b> products.</li>
#     <li><b>Electronics</b> and <b>Toys</b> have similar counts, both around <b>95</b> products.</li>
#     <li><b>Home</b> is the least frequent category among those shown, with approximately <b>90</b> products.</li>
#   </ul>
#
#   <p style="font-size: 16px; margin-top: 10px;">
#     ✅ Overall, the categories are relatively evenly distributed, with <b>Beauty</b> and <b>Clothing</b> having slightly higher counts than <b>Electronics</b>, <b>Toys</b>, and <b>Home</b>.
#   </p>
#
# </div>

# %% [markdown]
# <h4 style="font-family:Segoe UI,Tahoma,Geneva,Verdana,sans-serif; font-size:1.5em; color: #1ceb65ff; margin-top:20px; margin-bottom:10px;">
#    Brand
# </h4>

# %%
# Count brand frequencies
brand_counts = df['Brand'].value_counts().head(10).reset_index()
brand_counts.columns = ['Brand', 'count']

# Plot
plt.figure(figsize=(10, 6))
sns.barplot(
    data=brand_counts,
    x='Brand',
    y='count',
    hue='Brand',           # same as x to avoid future warning
    palette='Set2',
    legend=False
)

# Formatting
plt.title('Top 10 Brands by Product Count', fontsize=14, fontweight='bold')
plt.xlabel('Brand', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif; background-color: #ffffff; color: #333333; padding: 20px; line-height: 1.8; border-radius: 8px; box-shadow: 0 2px 6px rgba(0,0,0,0.05); margin-top: 30px;">
#
#   <p style="font-size: 18px; font-weight: 600; color: #2c3e50; margin-bottom: 15px;">
#     📊 This graph shows the top 10 brands by product count.
#   </p>
#
#   <ul style="font-size: 16px; padding-left: 20px;">
#     <li><b>BrandA</b> has the highest number of products, with a count of approximately <b>142</b>.</li>
#     <li><b>BrandB</b> and <b>BrandC</b> are quite close in product count, both around <b>125</b>.</li>
#     <li><b>BrandD</b> has the fewest products among the brands shown, with a count of around <b>108</b>.</li>
#   </ul>
#
#   <p style="font-size: 16px; margin-top: 10px;">
#     ✅ In summary, <b>BrandA</b> is the most dominant brand in terms of product quantity, while the other three brands shown have a relatively similar number of products, with <b>BrandD</b> being the least represented.
#   </p>
#
# </div>

# %% [markdown]
# <h4 style="font-family:Segoe UI,Tahoma,Geneva,Verdana,sans-serif; font-size:1.5em; color: #1ceb65ff; margin-top:20px; margin-bottom:10px;">
#    Material
# </h4>

# %%
# Count frequency of each material type
material_counts = df['Material'].value_counts().reset_index()
material_counts.columns = ['Material', 'Count']

# Plot
plt.figure(figsize=(8, 6))
sns.barplot(
    data=material_counts,
    x='Material',
    y='Count',
    hue='Material',       # To avoid the FutureWarning
    palette='pastel',
    legend=False
)

# Formatting
plt.title('Material Distribution', fontsize=14, fontweight='bold')
plt.xlabel('Material Type', fontsize=12)
plt.ylabel('Number of Products', fontsize=12)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif; background-color: #ffffff; color: #333333; padding: 20px; line-height: 1.8; border-radius: 8px; box-shadow: 0 2px 6px rgba(0,0,0,0.05); margin-top: 30px;">
#
#   <p style="font-size: 18px; font-weight: 600; color: #2c3e50; margin-bottom: 15px;">
#     🧱 This graph illustrates the distribution of products across different material types.
#   </p>
#
#   <ul style="font-size: 16px; padding-left: 20px;">
#     <li>🔩 <b>Metal</b> is the most common material, with approximately <b>108</b> products.</li>
#     <li>🧴 <b>Plastic</b> and 🧵 <b>Cotton</b> are very close in popularity, both having around <b>103</b> products.</li>
#     <li>🧪 <b>Glass</b> is slightly less common, with about <b>100</b> products.</li>
#     <li>🪵 <b>Wood</b> is the least represented material type among those shown, with roughly <b>88</b> products.</li>
#   </ul>
#
#   <p style="font-size: 16px; margin-top: 10px;">
#     ✅ In summary, <b>Metal</b> is the most frequently used material, followed closely by <b>Plastic</b> and <b>Cotton</b>. <b>Glass</b> and <b>Wood</b> are less common, with <b>Wood</b> being the least utilized material type in this dataset.
#   </p>
#
# </div>

# %% [markdown]
# <h3 style="font-family:Segoe UI,Tahoma,Geneva,Verdana,sans-serif; font-size:2.2em; color:#2E86C1; border-bottom:2px solid #1B4F72; padding-bottom:6px; margin-top:30px; margin-bottom:15px; font-weight:600;">
#   3.2 Numerical Variables
# </h3>
#
# <h4 style="font-family:Segoe UI,Tahoma,Geneva,Verdana,sans-serif; font-size:1.5em; color: #1ceb65ff; margin-top:20px; margin-bottom:10px;">
#    •	Weight(kg) Distribution:
# </h4>

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df['Weight(kg)'], bins=30, kde=True, color='skyblue')
plt.title('Distribution of Product Weights', fontsize=14, fontweight='bold')
plt.xlabel('Weight (kg)', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.tight_layout()


plt.figure(figsize=(8, 3))
sns.boxplot(x=df['Weight(kg)'], color='lightgreen')
plt.title('Box Plot of Product Weights', fontsize=14, fontweight='bold')
plt.xlabel('Weight (kg)', fontsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="font-family: 'Segoe UI', sans-serif; background: #ffffff; color: #333; padding: 20px; border-radius: 8px; box-shadow: 0 2px 6px rgba(0,0,0,0.05); line-height: 1.7; font-size: 16px;">
#
#   <p style="font-size: 18px; font-weight: 600; color: #2c3e50;">⚖️ Product Weight Insights (Box Plot & Histogram)</p>
#
#   <ul style="padding-left: 20px;">
#     <li>📦 <b>Box Plot:</b>
#       <ul>
#         <li>Median: ~2.8 kg</li>
#         <li>IQR: 1.5 kg to 3.8 kg</li>
#         <li>Range: 0.2 kg to 5 kg</li>
#         <li>✅ No outliers detected</li>
#       </ul>
#     </li>
#
# <li>📊 <b>Histogram + KDE:</b>
#       <ul>
#         <li>Weight range: 0–5 kg</li>
#         <li>⛰️ Peaks around: 0.5, 2.2, 2.8, and 4.5 kg</li>
#         <li>📈 Multi-modal distribution (not normal)</li>
#       </ul>
#     </li>
#
#   <li>🔍 <b>Combined:</b>
#       <ul>
#         <li>Most products fall in 1.5–3.8 kg range</li>
#         <li>No extreme values or outliers</li>
#       </ul>
#     </li>
#   </ul>
#
# </div>

# %% [markdown]
# <h4 style="font-family:Segoe UI,Tahoma,Geneva,Verdana,sans-serif; font-size:1.5em; color: #1ceb65ff; margin-top:20px; margin-bottom:10px;">
# •	Warranty(years) Distribution:</h4>

# %%
plt.figure(figsize=(8, 5))
sns.countplot(x='Warranty(years)', hue='Warranty(years)', data=df, palette='Set2', legend=False)
plt.title('Distribution of Warranty Periods', fontsize=14, fontweight='bold')
plt.xlabel('Warranty (Years)', fontsize=12)
plt.ylabel('Number of Products', fontsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="font-family: 'Segoe UI', sans-serif; background: #ffffff; color: #333; padding: 20px; border-radius: 8px; box-shadow: 0 2px 6px rgba(0,0,0,0.05); line-height: 1.7; font-size: 16px;">
#
#   <p style="font-size: 18px; font-weight: 600; color: #2c3e50;">🛡️ Distribution of Warranty Periods</p>
#
#   <ul style="padding-left: 20px;">
#     <li>📌 <b>3 Years:</b> ~130 products (most common)</li>
#     <li>📌 <b>0 Year:</b> ~129 products (almost same)</li>
#     <li>📌 <b>1 Year:</b> ~125 products</li>
#     <li>📌 <b>2 Years:</b> ~108 products (least common)</li>
#   </ul>
#
#   <p>🔍 <b>Summary:</b> Warranty periods are fairly evenly distributed, with 3 and 0 years slightly ahead.</p>
# </div>

# %%
df.sample(10)
# Out:
#     ProductID     Category   Brand Material  Weight(kg)  Warranty(years)  \
# 125     P0126       Beauty  BrandA    Glass        4.23                0
# 330     P0331         Home  BrandC   Cotton        3.02                0
# 241     P0242     Clothing  BrandC  Plastic        3.42                0
# 103     P0104  Electronics  BrandC  Plastic        2.43                0
# 350     P0351  Electronics  BrandD    Glass        3.95                0
# 456     P0457         Toys  BrandC    Glass        3.63                2
# 383     P0384       Beauty  BrandA    Metal        3.72                2
# 495     P0496     Clothing  BrandB    Glass        0.21                1
# 274     P0275         Home  BrandB  Plastic        0.98                1
# 77      P0078       Beauty  BrandB   Cotton        4.82                1
#
#      ProductRating  LaunchYear
# 125            2.6        2021
# 330            3.3        2020
# 241            4.9        2019
# 103            4.2        2023
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df.dtypes
# Out:
# ProductID           object
# Category            object
# Brand               object
# Material            object
# Weight(kg)         float64
# Warranty(years)      int64
# ProductRating      float64
# LaunchYear           int64
# dtype: object

# %% [markdown]
# # Unique Categories per Column

# %%
for col in ['Category', 'Brand', 'Material']:
    print(f"{col}: {df[col].nunique()} unique values")
# Out:
# Category: 5 unique values
# Brand: 4 unique values
# Material: 5 unique values

# %% [markdown]
# # values Count

# %%
# Category distribution
df['Category'].value_counts().plot(kind='bar', title='Product Category Distribution')
# Out:
# <Axes: title={'center': 'Product Category Distribution'}, xlabel='Category'>

# %%
# Brand distribution
df['Brand'].value_counts().head(10).plot(kind='bar', title='Top 10 Brands')
# Out:
# <Axes: title={'center': 'Top 10 Brands'}, xlabel='Brand'>

# %%
# Material distribution
df['Material'].value_counts().plot(kind='bar', title='Material Used')
# Out:
# <Axes: title={'center': 'Material Used'}, xlabel='Material'>

# %%
# Histogram for weight
sns.histplot(df['Weight(kg)'], kde=True)
plt.title("Weight Distribution")
# Out:
# Text(0.5, 1.0, 'Weight Distribution')

# %%
# Warranty
sns.countplot(x='Warranty(years)', data=df)
plt.title("Warranty (Years)")
# Out:
# Text(0.5, 1.0, 'Warranty (Years)')

# %%
# Product Rating
sns.histplot(df['ProductRating'])
plt.title("Product Rating Distribution")
# Out:
# Text(0.5, 1.0, 'Product Rating Distribution')

# %%
# | Column 1       | Column 2          | Relation Type           | Relation Validity ✅ | Reason                                                                  |
# | -------------- | ----------------- | ----------------------- | ------------------- | ----------------------------------------------------------------------- |
# | **Category**   | **ProductRating** | Categorical–Numerical   | ✅ Yes               | Alag categories ka customer satisfaction alag ho sakta hai.             |
# | **Brand**      | **ProductRating** | Categorical–Numerical   | ✅ Yes               | Har brand ka reputation aur quality alag hota hai.                      |
# | **Material**   | **ProductRating** | Categorical–Numerical   | ✅ Yes               | Material affect karta hai product ki durability aur user experience.    |
# | **Category**   | **Warranty**      | Categorical–Numerical   | ✅ Yes               | Electronics vs furniture ka warranty expectation different hota hai.    |
# | **Material**   | **Warranty**      | Categorical–Numerical   | ✅ Yes               | Some materials offer more warranty (metal vs plastic, etc.)             |
# | **Category**   | **Weight**        | Categorical–Numerical   | ✅ Yes               | Furniture heavier hoga, electronics lighter hoga — category affects it. |
# | **Brand**      | **Warranty**      | Categorical–Numerical   | ✅ Yes               | Premium brands longer warranty dete hain.                               |
# | **Category**   | **LaunchYear**    | Categorical–Numerical   | ✅ Yes               | New categories ka adoption track kar sakte hain.                        |
# | **LaunchYear** | **ProductRating** | Numerical–Numerical     | ✅ Yes               | Older products ka rating lower ho sakta hai, ya vice versa.             |
# | **Brand**      | **Material**      | Categorical–Categorical | ✅ Yes               | Some brands specialize in certain materials only.                       |
# | **Category**   | **Material**      | Categorical–Categorical | ✅ Yes               | Product type defines material — plastic in kitchen, wood in furniture.  |

# %% [markdown]
# # BiVariate Analysis

# %% [markdown]
# # ProductRating by Category (Boxplot)

# %%
category_rating = df.groupby('Category')['ProductRating'].agg(['mean', 'count']).sort_values(by='mean', ascending=False)

plt.figure(figsize=(10, 6))
sns.barplot(x=category_rating.index, y=category_rating['mean'], palette='viridis')
plt.title("Average Product Rating by Category")
plt.ylabel("Mean Product Rating")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

print(category_rating)
# Out:
# C:\Users\sachi\AppData\Local\Temp\ipykernel_24848\1014600141.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=category_rating.index, y=category_rating['mean'], palette='viridis')
#                  mean  count
# Category
# Clothing     3.856601    109
# Electronics  3.837719     95
# Beauty       3.825272    112
# Toys         3.789247     93
# Home         3.687839     91

# %% [markdown]
# # Average Product Rating by Top Brands

# %%
top_brands = df['Brand'].value_counts().head(10).index
brand_rating = df[df['Brand'].isin(top_brands)].groupby('Brand')['ProductRating'].agg(['mean', 'count']).sort_values(by='mean', ascending=False)

plt.figure(figsize=(10, 6))
sns.barplot(x=brand_rating.index, y=brand_rating['mean'], palette='magma')
plt.title("Average Product Rating by Top 10 Brands")
plt.ylabel("Mean Product Rating")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

print(brand_rating)
# Out:
# C:\Users\sachi\AppData\Local\Temp\ipykernel_24848\1338026433.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=brand_rating.index, y=brand_rating['mean'], palette='magma')
#             mean  count
# Brand
# BrandD  3.855097    108
# BrandC  3.810027    124
# BrandA  3.800649    143
# BrandB  3.752720    125

# %% [markdown]
# # Material vs ProductRating

# %%
material_rating = df.groupby('Material')['ProductRating'].mean().sort_values(ascending=False)

plt.figure(figsize=(10, 6))
sns.barplot(x=material_rating.index, y=material_rating.values, palette='Blues_d')
plt.title("Average Product Rating by Material")
plt.ylabel("Avg Rating")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\sachi\AppData\Local\Temp\ipykernel_24848\4179814575.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=material_rating.index, y=material_rating.values, palette='Blues_d')

# %% [markdown]
# # Category vs Warranty

# %%
category_warranty = df.groupby('Category')['Warranty(years)'].mean().sort_values(ascending=False)

plt.figure(figsize=(10, 6))
sns.barplot(x=category_warranty.index, y=category_warranty.values, palette='Greens_d')
plt.title("Average Warranty by Category")
plt.ylabel("Avg Warranty (Years)")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\sachi\AppData\Local\Temp\ipykernel_24848\1952994635.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=category_warranty.index, y=category_warranty.values, palette='Greens_d')

# %%
# Step 1: Calculate mean rating per material
material_rating = df.groupby('Material')['ProductRating'].mean()

# Step 2: Plot pie chart
plt.figure(figsize=(5,5))
plt.pie(material_rating, labels=material_rating.index, autopct='%1.1f%%', startangle=140, colors=plt.cm.Set3.colors)
plt.title("Average Product Rating Distribution by Material")
plt.axis('equal')  # Equal aspect ratio for perfect circle
plt.show()

# %% [markdown]
# # warranty vs Brand

# %%
top_brands = df['Brand'].value_counts().head(10).index
brand_warranty = df[df['Brand'].isin(top_brands)].groupby('Brand')['Warranty(years)'].mean().sort_values(ascending=False)

plt.figure(figsize=(5,5))
sns.barplot(x=brand_warranty.index, y=brand_warranty.values, palette='Oranges')
plt.title("Average Warranty by Top 10 Brands")
plt.ylabel("Avg Warranty (Years)")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\sachi\AppData\Local\Temp\ipykernel_24848\1603562274.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=brand_warranty.index, y=brand_warranty.values, palette='Oranges')

# %%
# Step 1: Calculate mean rating per material
material_rating = df.groupby('Brand')['ProductRating'].mean()

# Step 2: Plot pie chart
plt.figure(figsize=(5,5))
plt.pie(material_rating, labels=material_rating.index, autopct='%1.1f%%', startangle=140, colors=plt.cm.Set3.colors)
plt.title("Average Product Rating Distribution by Material")
plt.axis('equal')  # Equal aspect ratio for perfect circle
plt.show()

# %% [markdown]
# # Category vs Weight

# %%
category_weight = df.groupby('Category')['Weight(kg)'].mean().sort_values(ascending=False)

plt.figure(figsize=(5,5))
sns.barplot(x=category_weight.index, y=category_weight.values, palette='Purples')
plt.title("Average Product Weight by Category")
plt.ylabel("Avg Weight (kg)")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\sachi\AppData\Local\Temp\ipykernel_24848\2806780080.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=category_weight.index, y=category_weight.values, palette='Purples')

# %%
brand_material = pd.crosstab(df['Brand'], df['Material'])

plt.figure(figsize=(5,5))
sns.heatmap(brand_material, cmap='YlGnBu', linewidths=0.5)
plt.title("Brand vs Material Count Heatmap")
plt.xlabel("Material")
plt.ylabel("Brand")
plt.tight_layout()
plt.show()

# %%
# Count of products launched per brand per year
brand_year = df.groupby(['LaunchYear', 'Brand']).size().reset_index(name='Count')

plt.figure(figsize=(12, 6))
sns.lineplot(data=brand_year, x='LaunchYear', y='Count', hue='Brand', marker='o')
plt.title("Number of Products Launched by Brand Over the Years")
plt.xlabel("Launch Year")
plt.ylabel("Product Count")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Launch Year-wise Trend for Each Category

# %%
# Count of products launched per category per year
category_year = df.groupby(['LaunchYear', 'Category']).size().reset_index(name='Count')

plt.figure(figsize=(12, 6))
sns.lineplot(data=category_year, x='LaunchYear', y='Count', hue='Category', marker='o')
plt.title("Number of Products Launched by Category Over the Years")
plt.xlabel("Launch Year")
plt.ylabel("Product Count")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
material_rating = df.groupby('Material')['ProductRating'].mean().reset_index()
print(material_rating)
# Out:
#   Material  ProductRating
# 0   Cotton       3.799183
# 1    Glass       3.711833
# 2    Metal       3.848060
# 3  Plastic       3.844429
# 4     Wood       3.805862

# %% [markdown]
# # launch Year wsie by product count

# %%
brand_year = df.groupby(['LaunchYear', 'Brand'],sort=True,).size().reset_index(name='Count')
print(brand_year)
# Out:
#     LaunchYear   Brand  Count
# 0         2018  BrandA     23
# 1         2018  BrandB     32
# 2         2018  BrandC     21
# 3         2018  BrandD     17
# 4         2019  BrandA     20
# 5         2019  BrandB     15
# 6         2019  BrandC     21
# 7         2019  BrandD     12
# 8         2020  BrandA     30
# 9         2020  BrandB     16
# 10        2020  BrandC     22
# 11        2020  BrandD     25
# 12        2021  BrandA     20
# 13        2021  BrandB     20
# 14        2021  BrandC     17
# 15        2021  BrandD     22
# 16        2022  BrandA     22
# 17        2022  BrandB     15
# 18        2022  BrandC     22
# 19        2022  BrandD     16
# 20        2023  BrandA     28
# 21        2023  BrandB     27
# 22        2023  BrandC     21
# 23        2023  BrandD     16

# %% [markdown]
# BrandA is the most consistent top performer, peaking multiple times. <br>
# BrandC is stable and predictable, good for long-term planning.<br>
# BrandB shows volatility, but potential to recover.<br>
# BrandD is the weakest performer, needs improvement or may be niche-focused.<br>

# %%
df.columns = df.columns.str.strip().str.lower().str.replace('(', '').str.replace(')', '')
# Now columns like 'Weight(kg)' → 'weightkg', 'Warranty(years)' → 'warrantyyears'

# %% [markdown]
# # Univariate Analysis

# %% [markdown]
# # Category Distribution

# %%
sns.countplot(data=df, x='category', order=df['category'].value_counts().index)
plt.title("Distribution of Product Categories")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Brand distribution

# %%
sns.countplot(data=df, x='brand', order=df['brand'].value_counts().index)
plt.title("Brand Frequency")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
sns.countplot(data=df, x='material', order=df['material'].value_counts().index)
plt.title("Material Distribution")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Numerical

# %%
plt.figure(figsize=(10, 4))
sns.histplot(data=df, x='weightkg', bins=30, kde=True)
plt.title("Distribution of Weight (kg)")
plt.tight_layout()
plt.show()

# Optional boxplot
sns.boxplot(x=df['weightkg'])
plt.title("Boxplot of Weight (kg)")
plt.tight_layout()
plt.show()

# %%
sns.countplot(data=df, x='warrantyyears')
plt.title("Warranty Period Distribution")
plt.tight_layout()
plt.show()

# %%
sns.histplot(df['productrating'], bins=10, kde=True, color='orange')
plt.title("Distribution of Product Ratings")
plt.xlabel("Rating")
plt.tight_layout()
plt.show()

# %%
import numpy as np

# %%
grouped = df.groupby(['category', 'brand'])['productrating'].mean().reset_index()

plt.figure(figsize=(14, 7))
sns.barplot(data=grouped, x='category', y='productrating', hue='brand')
plt.title("Average Product Rating by Brand within Each Category")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
from scipy.stats import norm

def check_normality_all(df, cols):
    fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(14, 10))
    axes = axes.flatten()

    for i, col in enumerate(cols):
        data = df[col].dropna()
        mu, std = norm.fit(data)

        sns.histplot(data, bins=30, kde=True, stat='density', ax=axes[i], color='skyblue')
        xmin, xmax = axes[i].get_xlim()
        x = np.linspace(xmin, xmax, 100)
        p = norm.pdf(x, mu, std)
        axes[i].plot(x, p, 'r', linewidth=2)

        axes[i].set_title(f"{col.upper()} — μ={mu:.2f}, σ={std:.2f}")
        axes[i].set_xlabel(col)
        axes[i].set_ylabel("Density")

    plt.suptitle("Normal Distribution Check (with Red = Ideal Normal Curve)", fontsize=16)
    plt.tight_layout()
    plt.show()

# ✅ Column renaming to lowercase and formatting
df.columns = df.columns.str.strip().str.lower().str.replace('(', '').str.replace(')', '')

# ✅ Columns to check
num_cols = ['weightkg', 'warrantyyears', 'productrating', 'launchyear']

# ✅ Run the plot
check_normality_all(df, num_cols)

# %% [markdown]
# # Multivariate Analysis

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='weightkg', y='productrating', hue='material', style='category')
plt.title("Weight vs Rating — colored by Material, shaped by Category")
plt.tight_layout()
plt.show()

# %%
 sns.pairplot(df, vars=['weightkg', 'warrantyyears', 'productrating'], hue='category', palette='Set2')
plt.suptitle("Pairplot with Category Hue", y=1.02)
plt.tight_layout()
plt.show()

# %%
heatmap_data = df.pivot_table(index='material', columns='category', values='productrating', aggfunc='mean')

plt.figure(figsize=(10,6))
sns.heatmap(heatmap_data, annot=True, cmap='YlGnBu', fmt='.2f')
plt.title("Avg Rating by Material & Category")
plt.tight_layout()
plt.show()
