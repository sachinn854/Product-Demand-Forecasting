# %% [markdown]
# <div style="font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif; background-color: #f8f8f8; color: #4A4A4A; line-height: 1.7; padding: 20px; border-radius: 8px; box-shadow: 0 4px 8px rgba(0,0,0,0.05);">
#
#   <h1 style="font-size: 2.8em; color: #FF5733; border-bottom: 4px solid #C70039; padding-bottom: 15px; margin-bottom: 30px; font-weight: 700; text-shadow: 1px 1px 2px rgba(0,0,0,0.1);">
#     1. Introduction and Objectives
#   </h1>
#
#   <p style="font-size: 1.2em; margin-bottom: 18px; font-weight: 400;">
#     The primary objective of this EDA is to understand the underlying patterns, distributions, and relationships within the product data.
#     We aim to uncover insights that can inform business decisions related to
#     <strong style="color: #FFC300; font-weight: 700;">product development</strong>,
#     <strong style="color: #FFC300; font-weight: 700;">marketing strategies</strong>, and
#     <strong style="color: #FFC300; font-weight: 700;">inventory management</strong>.
#   </p>
#
#   <p style="font-size: 1.2em; margin-bottom: 10px; font-weight: 400;">
#     Specifically, we will investigate:
#   </p>
#
#   <ul style="font-size: 1.2em; margin-left: 20px; font-weight: 400;">
#     <li>📦 Distribution of products across different <strong style="color: #33C7FF;">categories</strong> and <strong style="color: #33C7FF;">brands</strong>.</li>
#     <li>⚙️ Characteristics of products based on <strong style="color: #33C7FF;">material</strong>, <strong style="color: #33C7FF;">weight</strong>, and <strong style="color: #33C7FF;">warranty</strong>.</li>
#     <li>⭐ Performance indicators like <strong style="color: #33C7FF;">product ratings</strong>.</li>
#     <li>📈 Trends in <strong style="color: #33C7FF;">product launches over time</strong>.</li>
#   </ul>
#
# </div>

# %% [markdown]
# <div style="font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif; background-color: #f8f8f8; color: #4A4A4A; line-height: 1.7; padding: 20px; border-radius: 8px; box-shadow: 0 4px 8px rgba(0,0,0,0.05); margin-top: 40px;">
#
#   <h1 style="font-size: 2.6em; color: #FF5733; border-bottom: 4px solid #C70039; padding-bottom: 15px; margin-bottom: 30px; font-weight: 700; text-shadow: 1px 1px 2px rgba(0,0,0,0.1);">
#     2. Data Overview
#   </h1>
#
#   <h2 style="font-size: 2em; color: #33C7FF; margin-top: 25px; margin-bottom: 12px; font-weight: 600;">
#     Summary Statistics & Data Types
#   </h2>
#
#   <p style="font-size: 1.2em; margin-bottom: 20px; font-weight: 400;">
#     Even after performing data cleaning, it is a good practice to verify that data types and summary statistics are as expected.
#     This serves as a quick sanity check before deep analysis.
#   </p>
#
#   <ul style="font-size: 1.15em; line-height: 1.8; padding-left: 20px;">
#     <li>
#       <strong style="color: #FFC300;">Data Types:</strong> Ensure that numerical columns like
#       <em>Weight(kg)</em>, <em>Warranty(years)</em>, <em>ProductRating</em>, and <em>LaunchYear</em>
#       are treated as numeric types, while categorical columns like <em>Category</em>, <em>Brand</em>, and
#       <em>Material</em> are handled as strings or object types.
#     </li>
#     <li>
#       <strong style="color: #FFC300;">Summary Statistics:</strong>
#       <ul style="padding-left: 20px;">
#         <li>
#           <strong>Numerical Columns:</strong> Mean, median, standard deviation, minimum, maximum, and quartiles.
#         </li>
#         <li>
#           <strong>Categorical Columns:</strong> Count of unique values and most frequent categories.
#         </li>
#       </ul>
#     </li>
#   </ul>
#
# </div>

# %% [markdown]
# <div style="font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif; background-color: #fefefe; color: #4A4A4A; line-height: 1.7; padding: 20px; border-radius: 8px; box-shadow: 0 4px 8px rgba(0,0,0,0.05); margin-top: 40px;">
#
#   <h1 style="font-size: 2.6em; color: #FF5733; border-bottom: 4px solid #C70039; padding-bottom: 15px; margin-bottom: 30px; font-weight: 700; text-shadow: 1px 1px 2px rgba(0,0,0,0.1);">
#     3. Univariate Analysis
#   </h1>
#
#   <p style="font-size: 1.2em; margin-bottom: 20px; font-weight: 400;">
#     This section focuses on understanding the distribution of each variable independently.
#   </p>
#
# </div>

# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\sachi\OneDrive\Product Demand Forecasting\3_CLEANED DATA\product_info_cleaned.csv")

# %% [markdown]
# <h3 style="font-family:Segoe UI,Tahoma,Geneva,Verdana,sans-serif; font-size:2.2em; color:#2E86C1; border-bottom:2px solid #1B4F72; padding-bottom:6px; margin-top:30px; margin-bottom:15px; font-weight:600;">
#   3.1 Categorical Variables
# </h3>
#
# <h4 style="font-family:Segoe UI,Tahoma,Geneva,Verdana,sans-serif; font-size:1.5em; color: #1ceb65ff; margin-top:20px; margin-bottom:10px;">
#    Category
# </h4>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Count frequency of each category
category_counts = df['Category'].value_counts().reset_index()
category_counts.columns = ['Category', 'count']

# Plot
plt.figure(figsize=(10, 6))
sns.barplot(
    data=category_counts,
    x='Category',
    y='count',
    hue='Category',           # <--- Fix: assign hue to x variable
    palette='viridis',
    legend=False              # <--- Hide legend since hue is same as x
)

# Formatting
plt.title('Distribution of Product Categories', fontsize=14, fontweight='bold')
plt.xlabel('Category', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif; background-color: #ffffff; color: #333333; padding: 20px; line-height: 1.8; border-radius: 8px; box-shadow: 0 2px 6px rgba(0,0,0,0.05); margin-top: 30px; border: 2px solid #6cb4f0;">
#
#   <p style="font-size: 18px; font-weight: 600; color: #2c3e50; margin-bottom: 15px;">
#     📊 This graph displays the distribution of product categories.
#   </p>
#
#   <ul style="font-size: 16px; padding-left: 20px;">
#     <li><b>Beauty</b> is the most frequent category, with a count of approximately <b>115</b> products.</li>
#     <li><b>Clothing</b> is the second most frequent, with a count of about <b>110</b> products.</li>
#     <li><b>Electronics</b> and <b>Toys</b> have similar counts, both around <b>95</b> products.</li>
#     <li><b>Home</b> is the least frequent category among those shown, with approximately <b>90</b> products.</li>
#   </ul>
#
#   <p style="font-size: 16px; margin-top: 10px;">
#     ✅ Overall, the categories are relatively evenly distributed, with <b>Beauty</b> and <b>Clothing</b> having slightly higher counts than <b>Electronics</b>, <b>Toys</b>, and <b>Home</b>.
#   </p>
#
# </div>

# %% [markdown]
# <h4 style="font-family:Segoe UI,Tahoma,Geneva,Verdana,sans-serif; font-size:1.5em; color: #1ceb65ff; margin-top:20px; margin-bottom:10px;">
#    Brand
# </h4>

# %%
# Count brand frequencies
brand_counts = df['Brand'].value_counts().head(10).reset_index()
brand_counts.columns = ['Brand', 'count']

# Plot
plt.figure(figsize=(10, 6))
sns.barplot(
    data=brand_counts,
    x='Brand',
    y='count',
    hue='Brand',           # same as x to avoid future warning
    palette='Set2',
    legend=False
)

# Formatting
plt.title('Top 10 Brands by Product Count', fontsize=14, fontweight='bold')
plt.xlabel('Brand', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif; background-color: #ffffff; color: #333333; padding: 20px; line-height: 1.8; border-radius: 8px; box-shadow: 0 2px 6px rgba(0,0,0,0.05); margin-top: 30px; border: 1.8px solid #66b3ff;">
#
#   <p style="font-size: 18px; font-weight: 600; color: #2c3e50; margin-bottom: 15px;">
#     📊 This graph shows the top 10 brands by product count.
#   </p>
#
#   <ul style="font-size: 16px; padding-left: 20px;">
#     <li><b>BrandA</b> has the highest number of products, with a count of approximately <b>142</b>.</li>
#     <li><b>BrandB</b> and <b>BrandC</b> are quite close in product count, both around <b>125</b>.</li>
#     <li><b>BrandD</b> has the fewest products among the brands shown, with a count of around <b>108</b>.</li>
#   </ul>
#
#   <p style="font-size: 16px; margin-top: 10px;">
#     ✅ In summary, <b>BrandA</b> is the most dominant brand in terms of product quantity, while the other three brands shown have a relatively similar number of products, with <b>BrandD</b> being the least represented.
#   </p>
#
# </div>

# %% [markdown]
# <h4 style="font-family:Segoe UI,Tahoma,Geneva,Verdana,sans-serif; font-size:1.5em; color: #1ceb65ff; margin-top:20px; margin-bottom:10px;">
#    Material
# </h4>

# %%
# Count frequency of each material type
material_counts = df['Material'].value_counts().reset_index()
material_counts.columns = ['Material', 'Count']

# Plot
plt.figure(figsize=(8, 6))
sns.barplot(
    data=material_counts,
    x='Material',
    y='Count',
    hue='Material',       # To avoid the FutureWarning
    palette='pastel',
    legend=False
)

# Formatting
plt.title('Material Distribution', fontsize=14, fontweight='bold')
plt.xlabel('Material Type', fontsize=12)
plt.ylabel('Number of Products', fontsize=12)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif; background-color: #ffffff; color: #333333; padding: 20px; line-height: 1.8; border-radius: 8px; box-shadow: 0 2px 6px rgba(0,0,0,0.05); margin-top: 30px; border: 1.8px solid #66b3ff;">
#
#   <p style="font-size: 18px; font-weight: 600; color: #2c3e50; margin-bottom: 15px;">
#     🧱 This graph illustrates the distribution of products across different material types.
#   </p>
#
#   <ul style="font-size: 16px; padding-left: 20px;">
#     <li>🔩 <b>Metal</b> is the most common material, with approximately <b>108</b> products.</li>
#     <li>🧴 <b>Plastic</b> and 🧵 <b>Cotton</b> are very close in popularity, both having around <b>103</b> products.</li>
#     <li>🧪 <b>Glass</b> is slightly less common, with about <b>100</b> products.</li>
#     <li>🪵 <b>Wood</b> is the least represented material type among those shown, with roughly <b>88</b> products.</li>
#   </ul>
#
#   <p style="font-size: 16px; margin-top: 10px;">
#     ✅ In summary, <b>Metal</b> is the most frequently used material, followed closely by <b>Plastic</b> and <b>Cotton</b>. <b>Glass</b> and <b>Wood</b> are less common, with <b>Wood</b> being the least utilized material type in this dataset.
#   </p>
#
# </div>

# %% [markdown]
# <h3 style="font-family:Segoe UI,Tahoma,Geneva,Verdana,sans-serif; font-size:2.2em; color:#2E86C1; border-bottom:2px solid #1B4F72; padding-bottom:6px; margin-top:30px; margin-bottom:15px; font-weight:600;">
#   3.2 Numerical Variables
# </h3>
#
# <h4 style="font-family:Segoe UI,Tahoma,Geneva,Verdana,sans-serif; font-size:1.5em; color: #1ceb65ff; margin-top:20px; margin-bottom:10px;">
#    •	Weight(kg) Distribution:
# </h4>

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df['Weight(kg)'], bins=30, kde=True, color='skyblue')
plt.title('Distribution of Product Weights', fontsize=14, fontweight='bold')
plt.xlabel('Weight (kg)', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.tight_layout()


plt.figure(figsize=(8, 3))
sns.boxplot(x=df['Weight(kg)'], color='lightgreen')
plt.title('Box Plot of Product Weights', fontsize=14, fontweight='bold')
plt.xlabel('Weight (kg)', fontsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="
#   font-family: 'Segoe UI', sans-serif;
#   background: #ffffff;
#   color: #333;
#   padding: 20px;
#   border-radius: 8px;
#   border: 2px solid #66b3ff; /* bluish border added */
#   box-shadow: 0 2px 6px rgba(0,0,0,0.05);
#   line-height: 1.7;
#   font-size: 16px;
# ">
#
#   <p style="font-size: 18px; font-weight: 600; color: #2c3e50;">⚖️ Product Weight Insights (Box Plot & Histogram)</p>
#
#   <ul style="padding-left: 20px;">
#     <li>📦 <b>Box Plot:</b>
#       <ul>
#         <li>Median: ~2.8 kg</li>
#         <li>IQR: 1.5 kg to 3.8 kg</li>
#         <li>Range: 0.2 kg to 5 kg</li>
#         <li>✅ No outliers detected</li>
#       </ul>
#     </li>
#
#   <li>📊 <b>Histogram + KDE:</b>
#       <ul>
#         <li>Weight range: 0–5 kg</li>
#         <li>⛰️ Peaks around: 0.5, 2.2, 2.8, and 4.5 kg</li>
#         <li>📈 Multi-modal distribution (not normal)</li>
#       </ul>
#     </li>
#
#    <li>🔍 <b>Combined:</b>
#       <ul>
#         <li>Most products fall in 1.5–3.8 kg range</li>
#         <li>No extreme values or outliers</li>
#       </ul>
#     </li>
#   </ul>
#
# </div>

# %% [markdown]
# <h4 style="font-family:Segoe UI,Tahoma,Geneva,Verdana,sans-serif; font-size:1.5em; color: #1ceb65ff; margin-top:20px; margin-bottom:10px;">
# •	Warranty(years) Distribution:</h4>

# %%
plt.figure(figsize=(8, 5))
sns.countplot(x='Warranty(years)', hue='Warranty(years)', data=df, palette='Set2', legend=False)
plt.title('Distribution of Warranty Periods', fontsize=14, fontweight='bold')
plt.xlabel('Warranty (Years)', fontsize=12)
plt.ylabel('Number of Products', fontsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="
#   font-family: 'Segoe UI', sans-serif;
#   background: #ffffff;
#   color: #333;
#   padding: 20px;
#   border-radius: 10px;
#   border: 2px solid #66b3ff; /* brighter bluish border */
#   box-shadow: 0 2px 6px rgba(0,0,0,0.04);
#   line-height: 1.7;
#   font-size: 16px;
# ">
#
#   <p style="font-size: 18px; font-weight: 600; color: #2c3e50;">🛡️ Distribution of Warranty Periods</p>
#
#   <ul style="padding-left: 20px;">
#     <li>📌 <b>3 Years:</b> ~130 products (most common)</li>
#     <li>📌 <b>0 Year:</b> ~129 products (almost same)</li>
#     <li>📌 <b>1 Year:</b> ~125 products</li>
#     <li>📌 <b>2 Years:</b> ~108 products (least common)</li>
#   </ul>
#
#   <p>🔍 <b>Summary:</b> Warranty periods are fairly evenly distributed, with 3 and 0 years slightly ahead.</p>
# </div>

# %% [markdown]
# <h4 style="font-family:Segoe UI,Tahoma,Geneva,Verdana,sans-serif; font-size:1.5em; color: #1ceb65ff; margin-top:20px; margin-bottom:10px;">
# •	ProductRating Distribution:</h4>

# %%
plt.figure(figsize=(8, 5))
sns.countplot(x='RatingBin', data=df, hue='RatingBin', palette='coolwarm', legend=False)
plt.title('Product Ratings (Binned)', fontsize=14, fontweight='bold')
plt.xlabel('Rating Range', fontsize=12)
plt.ylabel('Number of Products', fontsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="font-family: 'Segoe UI', sans-serif; background: #fff; color: #333; padding: 20px; border-radius: 10px; box-shadow: 0 0 10px rgba(0,0,0,0.05); line-height: 1.6;">
#
#   <h2 style="color: #0077cc;">📊 Product Ratings (Binned)</h2>
#
#   <ul>
#     <li>⭐ <strong>0-2:</strong> No products.</li>
#     <li>⭐ <strong>2-3:</strong> ~100 products.</li>
#     <li>⭐ <strong>3-4:</strong> ~195 products.</li>
#     <li>⭐ <strong>4-5:</strong> ~202 products (most).</li>
#   </ul>
#
#   <p>✅ <strong>Insight:</strong> Most products have ratings above 3 — indicating overall positive feedback. 👍</p>
#
# </div>

# %% [markdown]
# <h4 style="font-family:Segoe UI,Tahoma,Geneva,Verdana,sans-serif; font-size:1.5em; color: #1ceb65ff; margin-top:20px; margin-bottom:10px;">
# •	LaunchYear Distribution:</h4>

# %%
plt.figure(figsize=(8, 5))
sns.histplot(data=df, x='LaunchYear', bins=15, kde=False, color='skyblue', edgecolor='black')
plt.title('Distribution of Product Launch Years', fontsize=14, fontweight='bold')
plt.xlabel('Launch Year', fontsize=12)
plt.ylabel('Number of Products', fontsize=12)
plt.tight_layout()
launch_trend = df['LaunchYear'].value_counts().sort_index()
plt.figure(figsize=(8, 5))
sns.lineplot(x=launch_trend.index, y=launch_trend.values, marker='o', color='teal')
plt.title('Trend of Product Launches Over Years', fontsize=14, fontweight='bold')
plt.xlabel('Launch Year', fontsize=12)
plt.ylabel('Number of Products', fontsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="font-family: 'Segoe UI', sans-serif; background: #fff; color: #333; padding: 20px; border-radius: 10px; box-shadow: 0 0 10px rgba(0,0,0,0.05); line-height: 1.6;">
#
#   <h2 style="color: #0077cc;">📈 Product Launch Trends (2018–2023)</h2>
#
#   <ul>
#     <li>🚀 <strong>2018:</strong> ~93 launches</li>
#     <li>📉 <strong>2019:</strong> Dip to ~68</li>
#     <li>📈 <strong>2020:</strong> Peak at ~95</li>
#     <li>↘️ <strong>2021:</strong> ~79 launches</li>
#     <li>🔽 <strong>2022:</strong> Slight dip to ~75</li>
#     <li>🔼 <strong>2023:</strong> Rebound to ~92</li>
#   </ul>
#
#   <p>📊 <strong>Insight:</strong> Product launches fluctuated with peaks in <strong>2018, 2020, and 2023</strong>. The recent surge in 2023 suggests a strong recovery after dips in 2021–2022. 📦📈</p>
#
# </div>

# %% [markdown]
# <div style="font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif; background-color: #fefefe; color: #4A4A4A; line-height: 1.7; padding: 20px; border-radius: 8px; box-shadow: 0 4px 8px rgba(0,0,0,0.05); margin-top: 40px;">
#
#   <h1 style="font-size: 2.6em; color: #FF5733; border-bottom: 4px solid #C70039; padding-bottom: 15px; margin-bottom: 30px; font-weight: 700; text-shadow: 1px 1px 2px rgba(0,0,0,0.1);">
#     4. Bivariate Analysis
#   </h1>
#
#   <p style="font-size: 1.2em; margin-bottom: 20px; font-weight: 400;">
#     This section explores relationships between pairs of variables.
#   </p>
#
# </div>

# %% [markdown]
# <h4 style="font-family:Segoe UI,Tahoma,Geneva,Verdana,sans-serif; font-size:1.5em; color: #1ceb65ff; margin-top:20px; margin-bottom:10px;">
# •	Category vs. ProductRating:</h4>

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Category', y='ProductRating', data=df)  # Removed palette to avoid warning
plt.title('Product Rating by Category', fontsize=14, fontweight='bold')
plt.xlabel('Category', fontsize=12)
plt.ylabel('Product Rating', fontsize=12)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="font-family: 'Segoe UI', sans-serif; background: #fff; color: #333; padding: 20px; border-radius: 10px; box-shadow: 0 0 10px rgba(0,0,0,0.05); line-height: 1.6;">
#
#   <h2 style="color: #0077cc;">📦 Product Ratings by Category</h2>
#
#   <ul>
#     <li>💄 <strong>Beauty:</strong> Median ~3.9, IQR 3.1–4.5, great ratings overall 🌟</li>
#     <li>🧸 <strong>Toys:</strong> Median ~3.7, IQR 3.2–4.5, slightly below Beauty 👌</li>
#     <li>🏡 <strong>Home:</strong> Median ~3.65, IQR 3.05–4.3, ratings more spread out 📉</li>
#     <li>📱 <strong>Electronics:</strong> Median ~3.85, IQR 3.3–4.4, solid performance ⚡</li>
#     <li>👗 <strong>Clothing:</strong> Median ~3.8, IQR 3.3–4.5, consistent and high 💃</li>
#   </ul>
#
#   <p>📊 <strong>Insight:</strong> Most categories show ratings above <strong>3.5+</strong>, with <strong>Beauty</strong> leading in satisfaction. Rating variability is consistent, and no major outliers were spotted. 👍✨</p>
#
# </div>

# %% [markdown]
# <h4 style="font-family:Segoe UI,Tahoma,Geneva,Verdana,sans-serif; font-size:1.5em; color: #1ceb65ff; margin-top:20px; margin-bottom:10px;">
# •	Brand vs. ProductRating:</h4>

# %%
# Step 1: Get Top N Brands by frequency
top_brands = df['Brand'].value_counts().nlargest(10).index
df_top_brands = df[df['Brand'].isin(top_brands)]

# Step 2: Plot without hue, then color manually to avoid warning
plt.figure(figsize=(12, 6))
ax = sns.boxplot(x='Brand', y='ProductRating', data=df_top_brands)

# Step 3: Assign unique colors manually
colors = sns.color_palette('Set2', n_colors=len(top_brands))
for patch, color in zip(ax.artists, colors):
    patch.set_facecolor(color)

# Step 4: Customize plot
plt.title('Product Ratings by Top Brands', fontsize=14, fontweight='bold')
plt.xlabel('Brand', fontsize=12)
plt.ylabel('Product Rating', fontsize=12)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="font-family: 'Segoe UI', sans-serif; background: #fff; color: #333; padding: 20px; border-radius: 12px; box-shadow: 0 0 10px rgba(0,0,0,0.08); line-height: 1.6;">
#
#   <h2 style="color: #e67e22;">📦 Brand vs. Product Rating (Box Plot Analysis)</h2>
#   <p>🔍 This box plot shows the distribution of <strong>Product Ratings</strong> for the <strong>Top Brands</strong>. All brands reflect generally positive ratings! 🌟</p>
#
#   <ul>
#     <li><strong>BrandB:</strong> Median ⭐ ~3.75 | IQR: 3.1–4.4 | Spread: 2.5–5.0<br>📌 Wide spread, mostly positive reviews.</li>
#
#   <li><strong>BrandD:</strong> Median ⭐ ~3.9 | IQR: 3.3–4.5 | Spread: 2.6–5.0<br>🏆 Highest median → best overall satisfaction.</li>
#
#   <li><strong>BrandA:</strong> Median ⭐ ~3.85 | IQR: 3.25–4.3 | Spread: 2.5–5.0<br>👍 Comparable to BrandD but fewer peak ratings.</li>
#         <li><strong>BrandC:</strong> Median ⭐ ~3.8 | IQR: 3.1–4.5 | Spread: 2.5–5.0<br>🔄 Very similar to BrandB in distribution.</li>
#   </ul>
#
#   <h3 style="color:#16a085;">✨ Overall Insights</h3>
#   <ul>
#     <li>✅ All top brands have medians between <strong>3.75–3.9</strong>.</li>
#     <li>🥇 <strong>BrandD</strong> leads with the highest customer satisfaction.</li>
#     <li>📏 Rating spread is consistent across brands → stable performance.</li>
#     <li>🚫 No major outliers → minimal extreme reviews.</li>
#   </ul>
#
#   <p>📈 These patterns suggest strong and consistent product quality among the top brands.</p>
# </div>

# %% [markdown]
# <h4 style="font-family:Segoe UI,Tahoma,Geneva,Verdana,sans-serif; font-size:1.5em; color: #1ceb65ff; margin-top:20px; margin-bottom:10px;">
# •	Warranty(years) vs. ProductRating:</h4>

# %%
plt.figure(figsize=(10, 5))
sns.scatterplot(x='Warranty(years)', y='ProductRating', data=df, hue='Warranty(years)', palette='viridis', legend=False)
plt.title('Scatter Plot: Product Rating vs. Warranty Period', fontsize=14, fontweight='bold')
plt.xlabel('Warranty (Years)', fontsize=12)
plt.ylabel('Product Rating', fontsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="font-family: 'Segoe UI', sans-serif; background: #fff; color: #333; padding: 20px; border-radius: 10px; box-shadow: 0 0 10px rgba(0,0,0,0.05); line-height: 1.6;">
#
#   <h2 style="color: #0077cc;">⭐ Product Rating vs. Warranty Period 📊</h2>
#
#   <p>🛠️ <strong>Warranty Years</strong> are discrete: <code>0</code>, <code>1</code>, <code>2</code>, <code>3</code></p>
#
#   <ul>
#     <li>📦 <strong>0 Years:</strong> Ratings range from ⭐️2.5 to ⭐️5.0</li>
#     <li>📦 <strong>1 Year:</strong> Ratings from ⭐️2.6 to ⭐️5.0</li>
#     <li>📦 <strong>2 Years:</strong> Range is ⭐️2.6 to ⭐️4.9</li>
#     <li>📦 <strong>3 Years:</strong> Also ⭐️2.5 to ⭐️5.0</li>
#   </ul>
#
#   <p>⚠️ <strong>No Clear Correlation:</strong> Longer warranty ⛔ doesn’t mean higher rating. Product ratings appear fairly <strong>independent</strong> of warranty length.</p>
#
#   <p>🎨 <strong>Color Encoding:</strong> Likely indicates density or a third variable.</p>
#
#   <p>📌 <strong>Conclusion:</strong> Customers rate products across the full spectrum regardless of warranty period. Longer warranties don’t assure better reviews. 🧾✨</p>
#
# </div>

# %% [markdown]
# <h4 style="font-family:Segoe UI,Tahoma,Geneva,Verdana,sans-serif; font-size:1.5em; color: #1ceb65ff; margin-top:20px; margin-bottom:10px;">
# •	Category vs. Brand:</h4>

# %%
# Create a cross-tabulation of Category vs. Brand
cat_brand_counts = pd.crosstab(df['Category'], df['Brand'])

# Optional: Focus on top N brands to avoid overcrowding
top_brands = df['Brand'].value_counts().nlargest(10).index
cat_brand_counts = cat_brand_counts[top_brands]

# Plot heatmap
plt.figure(figsize=(12, 6))
sns.heatmap(cat_brand_counts, annot=True, fmt='d', cmap='YlGnBu', linewidths=0.5, linecolor='gray')
plt.title('Brand Distribution Across Categories', fontsize=14, fontweight='bold')
plt.xlabel('Brand', fontsize=12)
plt.ylabel('Category', fontsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="font-family: 'Segoe UI', sans-serif; background: #fff; color: #333; padding: 20px; border-radius: 10px; box-shadow: 0 0 10px rgba(0,0,0,0.05); line-height: 1.6;">
#   <h2 style="color: #0077cc;">🔥 Brand Distribution Across Categories 🔍</h2>
#
#   <p>🧊 <strong>Heatmap Highlights:</strong> Darker shades = more products per brand in a category.</p>
#
#   <ul>
#     <li>💄 <strong>Beauty:</strong> BrandC (30) 🔝, BrandD (29), BrandA (27), BrandB (26)</li>
#     <li>👗 <strong>Clothing:</strong> BrandA (34) 🏆, BrandB (30), BrandC (25), BrandD (20) 🔻</li>
#     <li>📱 <strong>Electronics:</strong> BrandC (27) 🥇, BrandA (26), BrandD (22), BrandB (20)</li>
#     <li>🏠 <strong>Home:</strong> BrandA/B (24 each), BrandC (23), BrandD (20) 🟥</li>
#     <li>🧸 <strong>Toys:</strong> BrandA (32) 🏅, BrandB (25), BrandC (19), BrandD (17) 🔽</li>
#   </ul>
#
#   <h3 style="color: #28a745;">💡 Key Insights:</h3>
#   <ul>
#     <li>⭐ <strong>BrandA</strong> dominates in <em>Clothing</em> (34) and <em>Toys</em> (32).</li>
#     <li>✨ <strong>BrandC</strong> shines in <em>Beauty</em> (30) and <em>Electronics</em> (27).</li>
#     <li>📊 <strong>BrandB</strong> shows a balanced distribution across all categories.</li>
#     <li>⚠️ <strong>BrandD</strong> consistently has lower counts, especially in <em>Toys</em> (17).</li>
#   </ul>
#
#   <p>🎯 <strong>Conclusion:</strong> <em>BrandA’s Clothing</em> (34) is the dataset’s highest product concentration, while <em>BrandD’s Toys</em> (17) is the lowest.</p>
# </div>

# %% [markdown]
# <h4 style="font-family:Segoe UI,Tahoma,Geneva,Verdana,sans-serif; font-size:1.5em; color: #1ceb65ff; margin-top:20px; margin-bottom:10px;">
# •	Category vs. Weight(kg):</h4>

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='Category', y='Weight(kg)', data=df, width=0.6)

plt.title('Weight Distribution Across Product Categories', fontsize=14, fontweight='bold')
plt.xlabel('Category', fontsize=12)
plt.ylabel('Weight (kg)', fontsize=12)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="background-color:#ffffff; color:#2c3e50; font-family:Arial, sans-serif; padding:20px; border-radius:10px;">
#   <h2 style="color:#e67e22;">📦 Weight Distribution by Category</h2>
#   <p>Box plot shows weight spread across categories:</p>
#
#   <ul>
#     <li><strong>💄 Beauty:</strong> Median ~2.6 kg</li>
#     <li><strong>🧸 Toys:</strong> Median ~2.8 kg</li>
#     <li><strong>🏠 Home:</strong> Median ~2.7 kg</li>
#     <li><strong>💻 Electronics:</strong> Lightest → ~2.5 kg</li>
#     <li><strong>👗 Clothing:</strong> Heaviest → ~2.9 kg</li>
#   </ul>
#
#   <h3 style="color:#2980b9;">📊 Summary:</h3>
#   <ul>
#     <li>All range ~0.2–5 kg</li>
#     <li>Medians close (2.5–2.9 kg)</li>
#     <li>No major outliers</li>
#   </ul>
# </div>

# %% [markdown]
# <h4 style="font-family:Segoe UI,Tahoma,Geneva,Verdana,sans-serif; font-size:1.5em; color: #1ceb65ff; margin-top:20px; margin-bottom:10px;">
# •	Material vs. Weight(kg):</h4>

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='Material', y='Weight(kg)', data=df,  width=0.6)

plt.title('Weight Distribution by Material Type', fontsize=14, fontweight='bold')
plt.xlabel('Material', fontsize=12)
plt.ylabel('Weight (kg)', fontsize=12)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="background-color:#ffffff; color:#2c3e50; font-family:Arial, sans-serif; padding:20px; border-radius:10px;">
#   <h2 style="color:#e67e22;">⚖️ Weight Distribution by Material</h2>
#   <p>This box plot compares the weight distribution across different materials.</p>
#
#   <ul>
#     <li><strong>🧵 Cotton:</strong> Median ~2.7 kg | Moderate spread.</li>
#     <li><strong>🧴 Plastic:</strong> Median ~2.8 kg | Broad lower quartile → includes lighter items.</li>
#     <li><strong>🪵 Wood:</strong> Median ~2.8 kg | Slightly heavier in middle 50%.</li>
#     <li><strong>🔩 Metal:</strong> Median ~2.5 kg | Lightest on average.</li>
#     <li><strong>🧊 Glass:</strong> Median ~2.6 kg | Among the lighter materials.</li>
#   </ul>
#
#   <h3 style="color:#2980b9;">📌 Key Takeaways:</h3>
#   <ul>
#     <li>🔸 All materials have similar median weights (2.5–2.8 kg).</li>
#     <li>🔸 Weight ranges from ~0.2 kg to ~4.9 kg for all.</li>
#     <li>🔸 Metal is generally lightest; Wood & Plastic slightly heavier.</li>
#     <li>✅ No extreme outliers found in any material.</li>
#   </ul>
# </div>

# %% [markdown]
# <div style="font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif; background-color: #fefefe; color: #4A4A4A; line-height: 1.7; padding: 20px; border-radius: 8px; box-shadow: 0 4px 8px rgba(0,0,0,0.05); margin-top: 40px;">
#
#   <h1 style="font-size: 2.6em; color: #FF5733; border-bottom: 4px solid #C70039; padding-bottom: 15px; margin-bottom: 30px; font-weight: 700; text-shadow: 1px 1px 2px rgba(0,0,0,0.1);">
#     5. Multivariate Analysis
#   </h1>
#
#   <p style="font-size: 1.2em; margin-bottom: 20px; font-weight: 400;">
#     This section explores interactions between three or more variables.
#   </p>
#
# </div>

# %% [markdown]
# <h4 style="font-family:Segoe UI,Tahoma,Geneva,Verdana,sans-serif; font-size:1.5em; color: #1ceb65ff; margin-top:20px; margin-bottom:10px;">
# •	Category, Brand, and ProductRating:</h4>

# %%
# Step 1: Calculate mean ratings for each Category-Brand group
grouped_data = df.groupby(['Category', 'Brand'])['ProductRating'].mean().reset_index()

# Step 2: Plot using Seaborn
plt.figure(figsize=(14, 7))
sns.barplot(data=grouped_data, x='Category', y='ProductRating', hue='Brand', errorbar=None, palette='Set3')

# Step 3: Formatting
plt.title('Average Product Rating by Brand within Each Category', fontsize=14, fontweight='bold')
plt.xlabel('Category', fontsize=12)
plt.ylabel('Average Product Rating', fontsize=12)
plt.legend(title='Brand', bbox_to_anchor=(1.05, 1), loc='upper left')  # Move legend outside
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="background:#fff; color:#2c3e50; font-family:Arial; padding:20px; border-radius:10px;">
#
#   <h2 style="color:#e67e22;">📊 Brand vs Category: Avg. Product Ratings</h2>
#
#   <ul>
#     <li>💄 <strong>Beauty:</strong> <span style="color:#27ae60;">BrandB</span> & <span style="color:#27ae60;">BrandD</span> lead (~3.9+)</li>
#     <li>👗 <strong>Clothing:</strong> <span style="color:#27ae60;">BrandD</span> best (~3.95)</li>
#     <li>💻 <strong>Electronics:</strong> <span style="color:#27ae60;">BrandD</span> top (~4.0)</li>
#     <li>🏠 <strong>Home:</strong> <span style="color:#2980b9;">BrandB</span> highest (~3.85), BrandD lowest</li>
#     <li>🧸 <strong>Toys:</strong> <span style="color:#27ae60;">BrandC</span> leads (~3.95)</li>
#   </ul>
#
#   <h3 style="color:#2980b9;">🔍 Overall Insights:</h3>
#   <ul>
#     <li>🏆 <strong>BrandD:</strong> Tops Electronics & Clothing, strong in Beauty</li>
#     <li>✨ <strong>BrandC:</strong> Leads Toys, solid in Beauty</li>
#     <li>⚖️ <strong>BrandB:</strong> Balanced performer, best in Home</li>
#     <li>👍 <strong>BrandA:</strong> Consistent, but never the highest</li>
#     <li>✅ All brands score well (mostly 3.5–4.0)</li>
#   </ul>
#
# </div>

# %% [markdown]
# <div style="border: 2px solid #3498db; border-radius: 10px; padding: 20px; background-color: #f9fcff; margin-top: 20px;">
#   <h2 style="color: #1a5276; font-family: 'Poppins', sans-serif;">🔍 6. Key Insights and Recommendations</h2>
#   <ul style="font-family: Arial, sans-serif; font-size: 16px; color: #2c3e50; line-height: 1.7;">
#     <li><strong>📈 Product Performance:</strong> Identify top and bottom performing <b>categories/brands</b> based on ratings.</li>
#     <li><strong>⚖️ Product Characteristics:</strong> Spot common <b>weight or warranty patterns</b> across different product types.</li>
#     <li><strong>📊 Market Trends:</strong> Track trends in <b>product launches</b> and their initial performance.</li>
#     <li><strong>🚨 Anomalies/Outliers:</strong> Flag unusual cases like <b>heavy items with low ratings</b> or <b>extremely long warranties</b>.</li>
#     <li><strong>💡 Business Implications:</strong> Use insights to refine <b>product strategy, marketing,</b> and <b>sales decisions</b>.</li>
#   </ul>
# </div>

# %% [markdown]
# <div style="border: 2px solid #28a745; border-radius: 10px; padding: 20px; background-color: #f9fff9; margin-top: 20px;">
#   <h2 style="color: #196f3d; font-family: 'Poppins', sans-serif;">🧭 7. Future Work</h2>
#   <ul style="font-family: Arial, sans-serif; font-size: 16px; color: #2c3e50; line-height: 1.7;">
#     <li><strong>🔍 Further Analysis:</strong> Explore specific segments like <b>low-rated products</b> or <b>emerging categories</b>.</li>
#     <li><strong>🧪 Hypothesis Testing:</strong> Test data-driven assumptions from observed trends.</li>
#     <li><strong>🧱 Feature Engineering:</strong> Derive useful new variables (e.g., <b>product age</b> from LaunchYear).</li>
#     <li><strong>🤖 Predictive Modeling:</strong> Leverage insights to build models for <b>ratings or sales predictions</b>.</li>
#   </ul>
# </div>
